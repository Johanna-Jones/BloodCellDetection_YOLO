# %% [markdown]
# # Predictions for YOLOv9, YOLOv8, YOLOv5

# %%
import pandas as pd
import torch
import os
import yaml
import matplotlib.pyplot as plt
from ultralytics import YOLO
from pathlib import Path
import pathlib
#from IPython.display import display, Image
import cv2
from os.path import join

# %%
# %cd /scratch/xw10/jj8584
# Out:
# /scratch/xw10/jj8584
# /scratch/sa4/test/miniconda3/envs/TEST4/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# # Define Global Variables and Functions

# %% [markdown]
# ## Display the Ground Truth Images used as Test

# %%
with open('/scratch/xw10/jj8584/DATA/data.yaml', 'r') as f:
    data_yaml = yaml.safe_load(f)
    
   
data_directory = '/scratch/xw10/jj8584/DATA'
test_img_dir = join(data_directory,'test/images')
test_labels_dir = join(data_directory,'test/labels')
    
class_names = data_yaml['names']

# %%
import random
from os.path import join
def ground_truth(n=5):
    # Number of images to randomly select
    num_images = n
    
    image_files = [f for f in pathlib.Path(test_img_dir).iterdir() if f.is_file()] # path object
    
    # randomly shuffle the images
    random.shuffle(image_files)
    
    # select the 5 randomly selected files
    return image_files[:num_images]

# %%
def annotate_ground_truth(image_ls):
   
    for select_img in selected_image_files:
    
        # set the image
        demo_image = select_img
    
        #retrieve the label's corresponding text file
        # / operator is used to join paths
        # 'stem' removes the file extension and matches the image to the annotation file
        demo_label =  pathlib.Path(test_labels_dir) / f"{select_img.stem}.txt" 
        
        # Load the image using OpenCV's imread function
        image = cv2.imread(str(demo_image))
    
        # Get the list of class names from the 'data' dictionary
        class_list = data_yaml['names']
    
        # Define a list of colors to be used to draw bounding boxes
        colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255)]
    
        # Get the height and width of the image
        height, width, _ = image.shape
    
        # Create an empty list T
        T = []
    
        with open(demo_label, "r") as file1:
            for line in file1.readlines():
                # Split the line into a list of strings
                split = line.split(" ")
    
                # Get the class id from the first element of the split list
                class_id = int(split[0])
    
                # Get the color corresponding to the class id from the 'colors' list
                color = colors[class_id]
                clazz = class_list[class_id]
                
                # Get the x, y, w, h bounding box coordinates from the split list
                x, y, w, h = float(split[1]), float(split[2]), float(split[3]), float(split[4])
    
                # Rescale the x, y, w, h values to the size of the image
                box = [int((x - 0.5*w)* width), int((y - 0.5*h) * height), int(w*width), int(h*height)]
    
                # Draw a rectangle on the image using the 'box' and 'color' values
                cv2.rectangle(image, box, color, 2)
    
                # Draw a filled rectangle for the class label on the image
                cv2.rectangle(image, (box[0], box[1] - 20), (box[0] + box[2], box[1]), color, -1)
    
                # Write the class label on the image
                cv2.putText(image, class_list[class_id], (box[0], box[1] - 5), cv2.FONT_HERSHEY_SIMPLEX, .5, (0,0,0))
    
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
            # Optionally resize the image (commented out in code)
        image = cv2.resize(image, (600, 600))
        plt.show()

# %%
selected_image_files = ground_truth(10)

# %%
selected_image_files
# Out:
# [PosixPath('/scratch/xw10/jj8584/DATA/test/images/BloodImage_00359_jpg.rf.03331bc3903822adbe982fe9e7cd061b.jpg'),
#  PosixPath('/scratch/xw10/jj8584/DATA/test/images/BloodImage_00278_jpg.rf.cfe491c301184766df6aa73fa48a7f33.jpg'),
#  PosixPath('/scratch/xw10/jj8584/DATA/test/images/BloodImage_00090_jpg.rf.cdbf8f6ed3b93fa902a0bc991132cb40.jpg'),
#  PosixPath('/scratch/xw10/jj8584/DATA/test/images/BloodImage_00134_jpg.rf.0d9da503b62e0034a2819a39cce7e7d9.jpg'),
#  PosixPath('/scratch/xw10/jj8584/DATA/test/images/BloodImage_00154_jpg.rf.e5b45569e9cbede1ed36f82f14566c29.jpg'),
#  PosixPath('/scratch/xw10/jj8584/DATA/test/images/BloodImage_00062_jpg.rf.1be1ca0ecdf783798fc10346baaa203e.jpg'),
#  PosixPath('/scratch/xw10/jj8584/DATA/test/images/BloodImage_00190_jpg.rf.3e0bf272a5f8ea902775e4cbc56c538c.jpg'),
#  PosixPath('/scratch/xw10/jj8584/DATA/test/images/BloodImage_00235_jpg.rf.283fff79a1188b82f5a544d381909c2d.jpg'),
#  PosixPath('/scratch/xw10/jj8584/DATA/test/images/BloodImage_00266_jpg.rf.2521623f1047a9502b2705a626ad6655.jpg'),
#  PosixPath('/scratch/xw10/jj8584/DATA/test/images/BloodImage_00191_jpg.rf.313648dd345edbdd005886613a01fe5d.jpg')]

# %%
annotate_ground_truth(selected_image_files)

# %% [markdown]
# ## Save Output Function

# %%
def save_output(ls, result_obj, date, model_name, folder):
    for i, pred in enumerate(result_obj):
        for j, img in enumerate(ls):
            if i == j:
                filename = img.stem.split('.')[0]
                pred.save(filename=f'runs/detect/predict/{folder}/{date}_{model_name}_{filename}.jpg')
                    #print(result)

# %% [markdown]
# # YOLOV9 Predictions

# %%
V9_val =YOLO('runs/detect/V9/V9_HP_tuning_1005/tune/weights/best.pt')
V9_pred = V9_val(selected_image_files, conf= 0.417)
# Out:
# 0: 416x416 1 Platelets, 19 RBCs, 1 WBC, 4.7ms
# 1: 416x416 2 Plateletss, 17 RBCs, 1 WBC, 4.7ms
# 2: 416x416 2 Plateletss, 4 RBCs, 1 WBC, 4.7ms
# 3: 416x416 2 Plateletss, 5 RBCs, 1 WBC, 4.7ms
# 4: 416x416 1 Platelets, 9 RBCs, 1 WBC, 4.7ms
# 5: 416x416 1 Platelets, 10 RBCs, 1 WBC, 4.7ms
# 6: 416x416 1 Platelets, 14 RBCs, 1 WBC, 4.7ms
# 7: 416x416 11 RBCs, 1 WBC, 4.7ms
# 8: 416x416 1 Platelets, 12 RBCs, 1 WBC, 4.7ms
# 9: 416x416 16 RBCs, 1 WBC, 4.7ms
# Speed: 0.7ms preprocess, 4.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)

# %%
save_output(ls=selected_image_files, result_obj= V9_pred,date='2205', model_name = "YOLOV9", folder = 'V9_Results/V9_FinalResults')

# %% [markdown]
# # YOLOV8 Predictions

# %% [markdown]
# ## Final Predictions
#
# - Run predictions at confidnce threshold of 41.1!

# %%
V8_val =YOLO('runs/detect/V8/V8_HP_Tune_0805/tune/weights/best.pt')
V8_pred = V8_val(selected_image_files, conf =0.411)
# Out:
# 0: 416x416 1 Platelets, 19 RBCs, 1 WBC, 11.2ms
# 1: 416x416 2 Plateletss, 18 RBCs, 1 WBC, 11.2ms
# 2: 416x416 3 Plateletss, 6 RBCs, 1 WBC, 11.2ms
# 3: 416x416 2 Plateletss, 5 RBCs, 1 WBC, 11.2ms
# 4: 416x416 1 Platelets, 11 RBCs, 1 WBC, 11.2ms
# 5: 416x416 2 Plateletss, 14 RBCs, 1 WBC, 11.2ms
# 6: 416x416 1 Platelets, 17 RBCs, 1 WBC, 11.2ms
# 7: 416x416 13 RBCs, 1 WBC, 11.2ms
# 8: 416x416 1 Platelets, 12 RBCs, 1 WBC, 11.2ms
# 9: 416x416 16 RBCs, 1 WBC, 11.2ms
# Speed: 1.9ms preprocess, 11.2ms inference, 219.0ms postprocess per image at shape (1, 3, 416, 416)

# %%
save_output(ls=selected_image_files, result_obj= V8_pred,date='2205', model_name = "YOLOV8", folder ='V8_results/V8_FinalResults')

# %%
V8_valid_full = YOLO('runs/detect/V8/trainV8_300424/weights/best.pt')
V8_pred_full = V8_valid_full(selected_image_files)
# Out:
# 0: 416x416 (no detections), 9.6ms
# 1: 416x416 (no detections), 9.6ms
# 2: 416x416 (no detections), 9.6ms
# 3: 416x416 (no detections), 9.6ms
# 4: 416x416 (no detections), 9.6ms
# Speed: 1.3ms preprocess, 9.6ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 416)

# %%
save_output(ls=selected_image_files, result_obj= V8_pred_full,date='3004', model_name = "YOLOV8_fullparams", folder ='V8_results/V8_full_params')

# %% [markdown]
# ### Step by Step Image processing (Val= False)
#
# ### Model: V8 train_loss_240524

# %%
V8_valid = YOLO('runs/detect/V8/train_loss_240524/weights/best.pt')
V8_pred = V8_valid(selected_image_files)
# Out:
# 0: 416x416 15 RBCs, 1 WBC, 9.6ms
# 1: 416x416 1 Platelets, 25 RBCs, 1 WBC, 9.6ms
# 2: 416x416 22 RBCs, 1 WBC, 9.6ms
# 3: 416x416 19 RBCs, 1 WBC, 9.6ms
# 4: 416x416 1 Platelets, 22 RBCs, 1 WBC, 9.6ms
# Speed: 0.8ms preprocess, 9.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)

# %%
save_output(ls=selected_image_files, result_obj= V8_pred,date='3004', model_name = "YOLOV8_loss2405", folder ='V8_results/V8_loss_2405')

# %% [markdown]
# # YOLOV5 Predictions

# %%
V5_val = YOLO('runs/detect/V5/V5_HP_tuning_1005/tune/weights/best.pt')
V5_pred = V5_val(selected_image_files, conf =0.381)
# Out:
# 0: 448x448 1 Platelets, 18 RBCs, 1 WBC, 10.2ms
# 1: 448x448 2 Plateletss, 18 RBCs, 1 WBC, 10.2ms
# 2: 448x448 1 Platelets, 3 RBCs, 1 WBC, 10.2ms
# 3: 448x448 2 Plateletss, 9 RBCs, 1 WBC, 10.2ms
# 4: 448x448 1 Platelets, 11 RBCs, 1 WBC, 10.2ms
# 5: 448x448 1 Platelets, 13 RBCs, 1 WBC, 10.2ms
# 6: 448x448 1 Platelets, 18 RBCs, 1 WBC, 10.2ms
# 7: 448x448 14 RBCs, 1 WBC, 10.2ms
# 8: 448x448 1 Platelets, 10 RBCs, 1 WBC, 10.2ms
# 9: 448x448 18 RBCs, 1 WBC, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 448)

# %%
save_output(ls=selected_image_files, result_obj= V5_pred,date='2205', model_name = "YOLOV5", folder ='V5_results/V5_FinalResults')

# %% [markdown]
# # YOLOV6 Predictions
